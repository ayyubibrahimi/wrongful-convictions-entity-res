# %%
from datamatch import (
    ThresholdMatcher,
    DissimilarFilter,
    NonOverlappingFilter,
    ColumnsIndex,
    JaroWinklerSimilarity,
    MaxScorer,
    SimSumScorer,
    AlterScorer,
    MultiIndex,
    AbsoluteScorer,
)
from datavalid.spinner import Spinner
import pandas as pd
from lib import clean_column_names
import re

# %% [markdown]
# ### rules
# # blocking features: first name, last name; rank description; officer context

# %%
def read():
    df = pd.read_csv("../data/input/reports-transcripts.csv").pipe(clean_column_names)
    return df

# %%
df = read()
df
# Out:
#                           officer_name  \
# 0                     Wayne Tamborella
# 1                       CapJohn Hughes
# 2                        MichaeChimano
# 3                      P/O Shawn Dupre
# 4      P/O DarryCoulon and DarryGordon
# ...                                ...
# 12215                     Travis Hayes
# 12216                           MWolff
# 12217                    Ryan Matthews
# 12218                              NaN
# 12219                              NaN
#
#                                          officer_context  \
# 0      Mentioned multiple times in various contexts, ...
# 1      Listed as the Night Supervisor at the scene of...
# 2      Mentioned as being part of the Third Police Di...
# 3      Listed as being part of the 301 unit in the Th...
# 4      Listed together as part of the 304 unit in the...
# ...                                                  ...
# 12215  Referred to as the defendant in a postconvicti...
# 12216  Speaks on behalf of the state, objecting to th...
# 12217  The case of Ryan Matthews is mentioned in rela...
# 12218  There are no specific individuals identified a...
# 12219                                                NaN
#
#                          officer_role  \
# 0      Lead Detective (Homicide Unit)
# 1                 Supervising Officer
# 2                            Sergeant
# 3                      Police Officer
# 4                     Police Officers
# ...                               ...
# 12215                       Defendant
# 12216            State Representative
# 12217      Involved in a related case
# 12218                             NaN
# 12219                             NaN
#
#                                              page_number  \
# 0      [21, 92, 31, 4, 96, 19, 90, 38, 38, 76, 90, 19...
# 1      [21, 92, 31, 4, 96, 19, 90, 38, 38, 76, 90, 19...
# 2      [21, 92, 31, 4, 96, 19, 90, 38, 38, 76, 90, 19...
# 3      [21, 92, 31, 4, 96, 19, 90, 38, 38, 76, 90, 19...
# 4      [21, 92, 31, 4, 96, 19, 90, 38, 38, 76, 90, 19...
# ...                                                  ...
# 12215                     [1, 2, 1, 1, 2, 1, 2, 2, 2, 1]
# 12216                     [1, 2, 1, 1, 2, 1, 2, 2, 2, 1]
# 12217                     [1, 2, 1, 1, 2, 1, 2, 2, 2, 1]
# 12218                     [2, 1, 2, 1, 2, 2, 2, 1, 1, 1]
# 12219                     [2, 2, 1, 1, 1, 2, 2, 1, 1, 2]
#
#                                                       fn  \
# 0                        Supplemental Police Report.json
# 1                        Supplemental Police Report.json
# 2                        Supplemental Police Report.json
# 3                        Supplemental Police Report.json
# 4                        Supplemental Police Report.json
# ...                                                  ...
# 12215  Exhibit 1b Hayes, Travis excerpt of transcript...
# 12216  Exhibit 1b Hayes, Travis excerpt of transcript...
# 12217  Exhibit 1b Hayes, Travis excerpt of transcript...
# 12218  Exhibit 1b Hayes, Travis excerpt of transcript...
# 12219  Exhibit 1b Hayes, Travis excerpt of transcript...
#
#                                                    query  \
# 0      Identify each individual in the transcript, by...
# 1      Identify each individual in the transcript, by...
# 2      Identify each individual in the transcript, by...
# 3      Identify each individual in the transcript, by...
# 4      Identify each individual in the transcript, by...
# ...                                                  ...
# 12215  Identify each individual in the transcript, by...
# 12216  Identify each individual in the transcript, by...
# 12217  Identify each individual in the transcript, by...
# 12218  Identify each individual in the transcript, by...
# 12219  Identify each individual in the transcript, by...
#
#                                 prompt_template_for_hyde  \
# 0      input_variables=['question'] template='\n    Y...
# 1      input_variables=['question'] template='\n    Y...
# 2      input_variables=['question'] template='\n    Y...
# 3      input_variables=['question'] template='\n    Y...
# 4      input_variables=['question'] template='\n    Y...
# ...                                                  ...
# 12215                                                NaN
# 12216                                                NaN
# 12217                                                NaN
# 12218                                                NaN
# 12219                                                NaN
#
#                                prompt_template_for_model  chunk_size  \
# 0      input_variables=['docs', 'question'] template=...         500
# 1      input_variables=['docs', 'question'] template=...         500
# 2      input_variables=['docs', 'question'] template=...         500
# 3      input_variables=['docs', 'question'] template=...         500
# 4      input_variables=['docs', 'question'] template=...         500
# ...                                                  ...         ...
# 12215                                                NaN         500
# 12216                                                NaN         500
# 12217                                                NaN         500
# 12218                                                NaN         500
# 12219                                                NaN         500
#
#        chunk_overlap  temperature   k  hyde  iteration  num_of_queries  \
# 0                250            1  20     1          1               1
# 1                250            1  20     1          1               1
# 2                250            1  20     1          1               1
# 3                250            1  20     1          1               1
# 4                250            1  20     1          1               1
# ...              ...          ...  ..   ...        ...             ...
# 12215            250            1  20     1          3               1
# 12216            250            1  20     1          3               1
# 12217            250            1  20     1          3               1
# 12218            250            1  20     1          5               1
# 12219            250            1  20     1          6               1
#
#                                          model       uid
# 0      gpt-3.5-turbo-1603-finetuned-300-labels  9cc6b328
# 1      gpt-3.5-turbo-1603-finetuned-300-labels  9cc6b328
# 2      gpt-3.5-turbo-1603-finetuned-300-labels  9cc6b328
# 3      gpt-3.5-turbo-1603-finetuned-300-labels  9cc6b328
# 4      gpt-3.5-turbo-1603-finetuned-300-labels  9cc6b328
# ...                                        ...       ...
# 12215  gpt-3.5-turbo-1603-finetuned-300-labels  9c161082
# 12216  gpt-3.5-turbo-1603-finetuned-300-labels  9c161082
# 12217  gpt-3.5-turbo-1603-finetuned-300-labels  9c161082
# 12218  gpt-3.5-turbo-1603-finetuned-300-labels  9c161082
# 12219  gpt-3.5-turbo-1603-finetuned-300-labels  9c161082
#
# [12220 rows x 17 columns]

# %%
def split_rows_with_multiple_officers(df):
    df = (
        df.drop("officer_name", axis=1)
        .join(
            df["officer_name"]
            .str.split("and", expand=True)
            .stack()
            .reset_index(level=1, drop=True)
            .rename("officer_name"),
            how="outer",
        )
        .reset_index(drop=True)
    )
    return df

df = df.pipe(split_rows_with_multiple_officers)

df
# Out:
#                                          officer_context  \
# 0      Mentioned multiple times in various contexts, ...
# 1      Listed as the Night Supervisor at the scene of...
# 2      Mentioned as being part of the Third Police Di...
# 3      Listed as being part of the 301 unit in the Th...
# 4      Listed together as part of the 304 unit in the...
# ...                                                  ...
# 12801  Referred to as the defendant in a postconvicti...
# 12802  Speaks on behalf of the state, objecting to th...
# 12803  The case of Ryan Matthews is mentioned in rela...
# 12804  There are no specific individuals identified a...
# 12805                                                NaN
#
#                          officer_role  \
# 0      Lead Detective (Homicide Unit)
# 1                 Supervising Officer
# 2                            Sergeant
# 3                      Police Officer
# 4                     Police Officers
# ...                               ...
# 12801                       Defendant
# 12802            State Representative
# 12803      Involved in a related case
# 12804                             NaN
# 12805                             NaN
#
#                                              page_number  \
# 0      [21, 92, 31, 4, 96, 19, 90, 38, 38, 76, 90, 19...
# 1      [21, 92, 31, 4, 96, 19, 90, 38, 38, 76, 90, 19...
# 2      [21, 92, 31, 4, 96, 19, 90, 38, 38, 76, 90, 19...
# 3      [21, 92, 31, 4, 96, 19, 90, 38, 38, 76, 90, 19...
# 4      [21, 92, 31, 4, 96, 19, 90, 38, 38, 76, 90, 19...
# ...                                                  ...
# 12801                     [1, 2, 1, 1, 2, 1, 2, 2, 2, 1]
# 12802                     [1, 2, 1, 1, 2, 1, 2, 2, 2, 1]
# 12803                     [1, 2, 1, 1, 2, 1, 2, 2, 2, 1]
# 12804                     [2, 1, 2, 1, 2, 2, 2, 1, 1, 1]
# 12805                     [2, 2, 1, 1, 1, 2, 2, 1, 1, 2]
#
#                                                       fn  \
# 0                        Supplemental Police Report.json
# 1                        Supplemental Police Report.json
# 2                        Supplemental Police Report.json
# 3                        Supplemental Police Report.json
# 4                        Supplemental Police Report.json
# ...                                                  ...
# 12801  Exhibit 1b Hayes, Travis excerpt of transcript...
# 12802  Exhibit 1b Hayes, Travis excerpt of transcript...
# 12803  Exhibit 1b Hayes, Travis excerpt of transcript...
# 12804  Exhibit 1b Hayes, Travis excerpt of transcript...
# 12805  Exhibit 1b Hayes, Travis excerpt of transcript...
#
#                                                    query  \
# 0      Identify each individual in the transcript, by...
# 1      Identify each individual in the transcript, by...
# 2      Identify each individual in the transcript, by...
# 3      Identify each individual in the transcript, by...
# 4      Identify each individual in the transcript, by...
# ...                                                  ...
# 12801  Identify each individual in the transcript, by...
# 12802  Identify each individual in the transcript, by...
# 12803  Identify each individual in the transcript, by...
# 12804  Identify each individual in the transcript, by...
# 12805  Identify each individual in the transcript, by...
#
#                                 prompt_template_for_hyde  \
# 0      input_variables=['question'] template='\n    Y...
# 1      input_variables=['question'] template='\n    Y...
# 2      input_variables=['question'] template='\n    Y...
# 3      input_variables=['question'] template='\n    Y...
# 4      input_variables=['question'] template='\n    Y...
# ...                                                  ...
# 12801                                                NaN
# 12802                                                NaN
# 12803                                                NaN
# 12804                                                NaN
# 12805                                                NaN
#
#                                prompt_template_for_model  chunk_size  \
# 0      input_variables=['docs', 'question'] template=...         500
# 1      input_variables=['docs', 'question'] template=...         500
# 2      input_variables=['docs', 'question'] template=...         500
# 3      input_variables=['docs', 'question'] template=...         500
# 4      input_variables=['docs', 'question'] template=...         500
# ...                                                  ...         ...
# 12801                                                NaN         500
# 12802                                                NaN         500
# 12803                                                NaN         500
# 12804                                                NaN         500
# 12805                                                NaN         500
#
#        chunk_overlap  temperature   k  hyde  iteration  num_of_queries  \
# 0                250            1  20     1          1               1
# 1                250            1  20     1          1               1
# 2                250            1  20     1          1               1
# 3                250            1  20     1          1               1
# 4                250            1  20     1          1               1
# ...              ...          ...  ..   ...        ...             ...
# 12801            250            1  20     1          3               1
# 12802            250            1  20     1          3               1
# 12803            250            1  20     1          3               1
# 12804            250            1  20     1          5               1
# 12805            250            1  20     1          6               1
#
#                                          model       uid      officer_name
# 0      gpt-3.5-turbo-1603-finetuned-300-labels  9cc6b328  Wayne Tamborella
# 1      gpt-3.5-turbo-1603-finetuned-300-labels  9cc6b328    CapJohn Hughes
# 2      gpt-3.5-turbo-1603-finetuned-300-labels  9cc6b328     MichaeChimano
# 3      gpt-3.5-turbo-1603-finetuned-300-labels  9cc6b328   P/O Shawn Dupre
# 4      gpt-3.5-turbo-1603-finetuned-300-labels  9cc6b328  P/O DarryCoulon
# ...                                        ...       ...               ...
# 12801  gpt-3.5-turbo-1603-finetuned-300-labels  9c161082      Travis Hayes
# 12802  gpt-3.5-turbo-1603-finetuned-300-labels  9c161082            MWolff
# 12803  gpt-3.5-turbo-1603-finetuned-300-labels  9c161082     Ryan Matthews
# 12804  gpt-3.5-turbo-1603-finetuned-300-labels  9c161082               NaN
# 12805  gpt-3.5-turbo-1603-finetuned-300-labels  9c161082               NaN
#
# [12806 rows x 17 columns]

# %%
# Drop rows where the officer's role does not correspond to law enforcement 

df.loc[:, "officer_role"] = df.officer_role.str.lower().str.strip()

officer_roles = ['officer', 'ofc.', 'lieutenant', 'lt.', 'detective', 'det.', 
                 'sergeant', 'sgt.', 'captain', 'cpt.', 'chief', 'inspector', 
                 'deputy', 'marshal', 'corporal', 'cpl.', 'commander', 'cmdr.', 
                 'agent', 'patrolman', 'trooper', 'sheriff', "coroner", "dr.", "doctor",
                 "p/o", "police officer"]

regex_pattern = '|'.join(officer_roles)
regex_pattern = r'\b(?:' + regex_pattern + r')\b'
regex_pattern = re.compile(regex_pattern, re.IGNORECASE)

df = df[df['officer_role'].fillna("").str.contains(regex_pattern)]

df.loc[:, "officer_role"] = (df
                             .officer_role.str.replace(r"^n/a(.+)", "", regex=True)
                             .str.replace(r"(.+)?presumed(.+)", "", regex=True)
                             .str.replace(r"(.+)?(not explicitly mentioned as a law enforcement officer|not a law enforcement officer)(.+)?", "", regex=True)
                             .str.replace(r"(.+)?(suspect|civilian|unclear from the context|role not specified)(.+)?", "", regex=True)
)

df = df[~((df.officer_role == ""))]

df.shape

df.officer_role.unique()
# Out:
# array(['lead detective (homicide unit)', 'supervising officer',
#        'sergeant', 'police officer', 'detective', 'captain',
#        'reporting officer', 'patrol officer', 'deputy', 'corporal',
#        "coroner's office investigator", 'lead detective',
#        'homicide detective', 'investigating detective',
#        'transporting officer', 'arresting officer', 'warrant officer',
#        'officer', 'investigating officer',
#        'officer attending magistrate court', 'first arresting officer',
#        'second arresting officer', 'crime scene technician sergeant',
#        'responding officer', 'assisting officer', 'assistant coroner',
#        'lead detective (homicide division)',
#        'detective, assigned to the m. c. i. unit of the seventh district',
#        'detective, assigned to the m.c.i. unit of the seventh district',
#        'coroner', "coroner's office staff",
#        'officer name: p.o. raymond loosemore \nofficer context: cleared several burglaries in the area through the identification of fingerprints. \nofficer role: police officer',
#        'doctor', 'police officer, crime lab analyst',
#        'police officer, crime lab technician',
#        'criminalist \n\nofficer name', 'crime lab officer',
#        'involved in the investigation, possibly a detective or officer.',
#        'field unit commander', 'detective, sergeant',
#        'commander, bureau commander', 'lieutenant',
#        'detective, crime scene technician',
#        'reporting officer, lead investigator, oncall detective',
#        'captain, commander of the detective bureau',
#        'lieutenant, crime scene technician', 'sergeant, detective',
#        'first responder sergeant', 'reporting sergeant',
#        'potential typo, intended to indicate detective sergeant',
#        'oncall detective, lead investigator, reporting officer',
#        'field unit patrolman', 'commander of the detective bureau',
#        'detective sergeant',
#        'reporting officer, case officer, lead investigator',
#        'lead investigating detective, oncall detective',
#        'captain, detective bureau commander', 'assisting detective',
#        'lieutenant, investigating officer',
#        'lieutenant, criminal investigations bureau',
#        'public information officer', 'officer on scene',
#        'theft prevention officer', 'security officer',
#        'reporting party, possibly a security or loss prevention officer',
#        'property recovery officer', 'mall security officer',
#        'paid detail officer', 'recovery officer', 'detective (jp542)',
#        'mounted officer', 'task force commander',
#        'task force sergeant, reporting officer', 'task force detective',
#        'task force sergeant, robbery section',
#        'task force detective, robbery section',
#        'task force detective, general assignment',
#        'vieux carre unit officer', 'vieux carre unit sergeant',
#        'lower quarter crime prevention officer', 'crime lab unit officer',
#        'crime lab unit sergeant', 'robbery detective',
#        'general assignment detective', 'rape detective',
#        'patrol sergeant', 'commander', 'detective supervisor',
#        'primary officer', 'crime prevention officer',
#        'primary crime lab officer', 'police sergeant',
#        'uniformed officer', 'detective (homicide division)',
#        'lineup detective', 'robbery unit detective',
#        'lineup conducting detective', 'lineup contact detective',
#        'commanding officer', 'questioning officer',
#        'homicide division officer', 'onscene officer',
#        'testifying detective', 'testifying officer', 'officer role:',
#        'assisted detective', 'criminalist, former rape detective',
#        'medical doctor', 'reporting officer \n\nofficer',
#        'police officer (crime lab)',
#        'patrol officer, evidence technician',
#        'detective \n\nofficer name', 'special agent', 'agent',
#        'chief of appeals', 'criminalist, detective',
#        'lead detective (rape investigations section)',
#        'lead police officer', 'escorting officer',
#        'crime area detective, lead detective',
#        'criminalist, detective, rape detective', 'identifying officer',
#        'general law enforcement officer', 'typing officer', 'chief',
#        'chief or supervisor', 'p/o (police officer)',
#        'officer (records division, criminal records section)',
#        'detective in the third district', 'commander, third d.i.u.',
#        'verifying officer', 'investigating detective, lead investigator',
#        'supervising sergeant', "coroner's investigator",
#        'arresting detective', "coroner's chauffeur", 'assistant chief',
#        'training officer', 'assigned officer', 'chief officer',
#        'crime scene section officer', 'working police officer',
#        'directing officer', 'securing officer',
#        'crime scene handling officer', 'scene investigating officer',
#        'absent officer', 'lead officer', 'homicide unit officer',
#        'lead homicide detective', 'detective, crime lab personnel',
#        'crime scene detective', 'onscene commander',
#        'scene securing officer', 'nonparticipating officer',
#        'trained officer', 'collecting officer', 'filling officer',
#        'crime scene officer', 'collaborating officer',
#        'highranking officer', 'state police officer',
#        'officer of the crime lab', 'homicide officer',
#        'correctional officer',
#        "chief investigator for the district attorney's office",
#        "officer from the criminal sheriff's office",
#        'sergeant with the major offense bureau', 'investigating sergeant',
#        'saturation officer', 'district officer',
#        'scene preservation officer', 'first district police officer',
#        "coroner's chauffer", 'interrogating detective',
#        'presenting officer', 'interrogating officer',
#        'detective, homicide division', 'officer (evidence collection)',
#        'officer (evidence analysis)', 'hotel security officer',
#        'not specified, but assumed to be a hotel security officer',
#        'patrolman', 'investigative officer', 'coroner chauffer',
#        'lead investigating detective', 'peace officer',
#        'evidence seizure officer', 'deputy officer', 'morgue officer',
#        'investigating officer, detective', 'supervising lieutenant',
#        'crime lab sergeant', 'observing officer', "coroner's assistant",
#        'coroner assistant', 'supporting sergeant',
#        "coroner's office assistant", 'unit officer',
#        "orleans parish coroner's office investigator",
#        'forensic pathologist/coroner', 'deputy superintendent',
#        'first responder officer', 'potential witness detective',
#        'officer, homicide investigator',
#        'detective, homicide investigator',
#        'primary investigating detective', "sheriff's office personnel",
#        'investigating officer, crime scene investigator',
#        'deputy sheriff', 'officer name', 'reviewing officer',
#        'homicide investigator, lead detective',
#        'detective, lead investigator', 'lead investigator, detective',
#        'advising detective',
#        "officer or official associated with the sheriff's office",
#        'chief of homicide division', 'city police officer',
#        'scene investigation officer', 'composite sketch officer',
#        'evidence collection officer', 'field officer',
#        'investigating officer, arresting officer, lineup coordinator',
#        'identifying officer, witness statement officer',
#        'detective, photographic lineup officer', 'detective bureau',
#        'case officer/report writer', 'case officer/coordinator',
#        'case officer', 'case agent, coordinator', "sheriff's deputy",
#        'case officer, coordinator', 'detective, dna analyst',
#        'detective, evidence collector', 'detective, forensic expert',
#        'captain, case coordinator', 'confession taking officer',
#        'chief of appeals division', 'captain, investigator',
#        'chief investigator, investigator, captain',
#        'chief investigator, captain', 'officer (interrogation unit)',
#        'lieutenant, nopd officer', 'interviewing officer',
#        'officer, detective',
#        'part of the office hierarchy, chief of screening',
#        'incident report officer', 'captain (blood evidence)',
#        'identification officer', 'lead detective, lead investigator',
#        'homicide detective, lead investigator',
#        'officer in charge of records', 'robbery division sergeant',
#        'crime scene investigative officer', 'task force unit officer',
#        'detective, homicide section', 'general police officer',
#        'fbi agent', 'nopd robbery detective', 'chief (trials division)',
#        'chief of trials', 'detective (homicide)',
#        'detective (armed robbery division)',
#        'eyewitness or identifying officer',
#        'detective, screener, assistant district attorney',
#        'involved in the reginald adams case, detective',
#        'lead detective on a homicide case', 'court officer',
#        'lieutenant, commander of the armed robbery section',
#        'detective, police sergeant',
#        'investigating detective, potentially also a crime scene technician.',
#        'lead detective.', 'detective, criminalist, medical technologist',
#        'officer context:  \nofficer role:',
#        'lead detective (robbery unit)',
#        'lead detective (robbery division)', 'crime scene sergeant',
#        'lead detective (rape unit)', 'handling detective (rape unit)',
#        'detective (forensic)', 'judicial officer', 'fingerprint officer',
#        'crime lab detective', 'crime scene supervisor sergeant',
#        'general officer',
#        'technician officer name: sergeant roach (spelled phonetically)  officer context: mentioned as the supervisor on the scene for the crime scene section during a particular night. officer role: supervisor officer name: officer rodriguez  officer context: noted as someone who may have trained the speaker in the initial stages at the crime lab. officer role: training officer officer name: detective gebbia  officer context: discussed as someone who was filled in by the speaker about their role in the incident. officer role: lead detective officer name: officer vanetia  officer context: mentioned as another officer assigned to work on a specific case. officer role: investigating officer',
#        'detective, crime lab division', 'processing detective',
#        'police officer, crime lab personnel', 'officer on patrol',
#        'captain, nord grise lab', 'patrolling officer',
#        'crime lab captain', 'collaborating detective',
#        'lead detective or interrogating officer',
#        'lead detective or investigator',
#        'detective or possibly a supervisor.',
#        'judge or former police officer.',
#        'judge, former new orleans police officer',
#        'homicide division detective',
#        'senior police officer in charge of the latent finger print section',
#        'detective (child abuse unit)',
#        'former patrolman, former crime scene technician',
#        'coroner of orleans parish',
#        "deputy (orleans criminal sheriff's department)",
#        'senior police officer (latent finger print section)',
#        'senior police officer', 'new orleans police officer',
#        'senior police officer in charge of the latent prints, expert in identifying and reading fingerprints',
#        'homicide division detective, crime scene technician',
#        'supervisor, officer',
#        'police officer, possibly a patrol officer.',
#        'colleague or associate of officer reilly.',
#        'police officer, possibly a detective.',
#        'selfidentified as a detective.', 'medical officer',
#        'first district officer, scene investigation supervisor',
#        'detective, homicide division officer',
#        'burglary division officer', 'detective, investigating officer',
#        'former homicide detective, burglary division detective'],
#       dtype=object)

# %%
def split_name(name):
    if pd.isnull(name) or name.strip() == '':
        return ['Unknown', 'Unknown']

    # Remove common prefixes, suffixes, and job titles with case-insensitive matching
    name = re.sub(r'^(Reporting Officer|Detective|P\/O|Officer|Police Officer|Chief|Chief of Trials|Police|Coroner\'s|Coroner\'s Investigator|Unit #\d+Of|Driver|Cap|Superintendent|Not specified)\s*', '', name, flags=re.IGNORECASE)
    name = re.sub(r'\s*(Badge\s*\d+|Unit\s*#\d+|Type\s*Name|Mentioned\s*Again|Later|\(.*?\))\s*$', '', name, flags=re.IGNORECASE)

    # Adjust regex to handle concatenated names better, including those with no clear separator
    # This pattern looks for a lowercase letter followed by an uppercase letter and inserts a space
    name = re.sub(r'(?<=[a-z])([A-Z])', r' \1', name)

    # Handle names starting with two capital letters, removing the first if followed by lowercase letters
    name = re.sub(r'^([A-Z])([A-Z][a-z]+)', r'\2', name)

    # Split the name
    parts = name.split()
    if len(parts) == 1:
        return ['Unknown', parts[0]]
    elif len(parts) >= 2:
        return [parts[0], ' '.join(parts[1:])]
    else:
        return ['Unknown', 'Unknown']


df[['first_name', 'last_name']] = df['officer_name'].apply(lambda x: pd.Series(split_name(x)))

df.loc[:, "first_name"] = df.first_name.str.lower().str.strip()
df.loc[:, "last_name"] = df.last_name.str.lower().str.strip()

df.loc[:, "fc"] = df.first_name.map(lambda x: x[:5])
df.loc[:, "lc"] = df.last_name.map(lambda x: x[:5])

full_names = df.first_name.str.cat(df.last_name, sep=" ")


df = df[["first_name", "last_name", "fc", "lc", "officer_role", "officer_context"]]

df
# Out:
#       first_name    last_name     fc     lc                    officer_role  \
# 0          wayne   tamborella  wayne  tambo  lead detective (homicide unit)
# 1           john       hughes   john  hughe             supervising officer
# 2         michae      chimano  micha  chima                        sergeant
# 3          shawn        dupre  shawn  dupre                  police officer
# 6          audie      jackson  audie  jacks                  police officer
# ...          ...          ...    ...    ...                             ...
# 12745  gwendolyn      norwood  gwend  norwo                      lieutenant
# 12746       gary       dupard   gary  dupar                       detective
# 12747         la  fleur young     la  fleur                       detective
# 12748    unknown         rice  unkno   rice                        sergeant
# 12749      lloyd        clark  lloyd  clark                  police officer
#
#                                          officer_context
# 0      Mentioned multiple times in various contexts, ...
# 1      Listed as the Night Supervisor at the scene of...
# 2      Mentioned as being part of the Third Police Di...
# 3      Listed as being part of the 301 unit in the Th...
# 6      Handling the district report at the scene of a...
# ...                                                  ...
# 12745  Mentioned as the immediate supervisor of the i...
# 12746  Mentioned as someone who assisted the lead inv...
# 12747  Mentioned as the detective the lieutenant swit...
# 12748  Mentioned as the person who was over the case ...
# 12749  Mentioned as someone the speaker can't recall ...
#
# [7210 rows x 6 columns]

# %%
df.loc[:, "first_name"] = df.first_name.str.lower().str.strip()
df.loc[:, "last_name"] = df.last_name.str.lower().str.strip()

df.loc[:, "fc"] = df.first_name.map(lambda x: x[:5])
df.loc[:, "lc"] = df.last_name.map(lambda x: x[:5])

full_names = df.first_name.str.cat(df.last_name, sep=" ")


df = df[["first_name", "last_name", "fc", "lc", "officer_role", "officer_context"]]

def jarowink_matcher(personnel):
    excel_path = "../data/output/jarowink_matches.xlsx"
    per = personnel
    per
    matcher = ThresholdMatcher(
        index=MultiIndex(
            [
                ColumnsIndex(["fc", "lc"]),
            ]
        ),
        scorer=MaxScorer(
            [
                AlterScorer(
                    scorer=SimSumScorer(
                        {
                            "first_name": JaroWinklerSimilarity(),
                            "last_name": JaroWinklerSimilarity(),
                        }
                    ),
                    # but for pairs that have the same name and their name is common
                    values=full_names,
                    # give a penalty of -.2 which is enough to eliminate them
                    alter=lambda score: score - 0.2,
                ),
            ]
        ),
        dfa=per,
    )
    decision = .5
    with Spinner("saving matched clusters to Excel file"):
        matcher.save_clusters_to_excel(excel_path, decision, lower_bound=decision)
    clusters = matcher.get_index_clusters_within_thresholds(decision)
    print("saved %d clusters to %s" % (len(clusters), excel_path))

    return clusters

# %%
jarowink_matcher(df)
# Out:
#   saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving matched clusters to Excel file saving m ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/ayyub/Desktop/entity-resolution/wrongful-convictions-entity-res/src/src.ipynb Cell 9 line 1
# ----> <a href='vscode-notebook-cell:/Users/ayyub/Desktop/entity-resolution/wrongful-convictions-entity-res/src/src.ipynb#X11sZmlsZQ%3D%3D?line=0'>1</a> jarowink_matcher(df)
#
# /Users/ayyub/Desktop/entity-resolution/wrongful-convictions-entity-res/src/src.ipynb Cell 9 line 3
#      <a href='vscode-notebook-cell:/Users/ayyub/Desktop/entity-resolution/wrongful-convictions-entity-res/src/src.ipynb#X11sZmlsZQ%3D%3D?line=28'>29</a> decision = .5
#      <a href='vscode-notebook-cell:/Users/ayyub/Desktop/entity-resolution/wrongful-convictions-entity-res/src/src.ipynb#X11sZmlsZQ%3D%3D?line=29'>30</a> with Spinner("saving matched clusters to Excel file"):
# ---> <a href='vscode-notebook-cell:/Users/ayyub/Desktop/entity-resolution/wrongful-convictions-entity-res/src/src.ipynb#X11sZmlsZQ%3D%3D?line=30'>31</a>     matcher.save_clusters_to_excel(excel_path, decision, lower_bound=decision)
#      <a href='vscode-notebook-cell:/Users/ayyub/Desktop/entity-resolution/wrongful-convictions-entity-res/src/src.ipynb#X11sZmlsZQ%3D%3D?line=31'>32</a> clusters = matcher.get_index_clusters_within_thresholds(decision)
#      <a href='vscode-notebook-cell:/Users/ayyub/Desktop/entity-resolution/wrongful-convictions-entity-res/src/src.ipynb#X11sZmlsZQ%3D%3D?line=32'>33</a> print("saved %d clusters to %s" % (len(clusters), excel_path))
#
# File /opt/homebrew/lib/python3.11/site-packages/datamatch/matchers.py:456, in ThresholdMatcher.save_clusters_to_excel(self, name, match_threshold, lower_bound, include_exact_matches)
#     427 """Save matched clusters to an Excel file.
#     428
#     429 This will create an Excel file with two sheets:
#    (...)
#     450 :rtype: :obj:`None`
#     451 """
#     452 with pd.ExcelWriter(name) as writer:
#     453     self.get_clusters_within_threshold(
#     454         lower_bound,
#     455         include_exact_matches
# --> 456     ).to_excel(writer, sheet_name='All clusters')
#     457     self._decision_series(
#     458         match_threshold
#     459     ).to_excel(writer, sheet_name="Decision")
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/util/_decorators.py:333, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     327 if len(args) > num_allow_args:
#     328     warnings.warn(
#     329         msg.format(arguments=_format_argument_list(allow_args)),
#     330         FutureWarning,
#     331         stacklevel=find_stack_level(),
#     332     )
# --> 333 return func(*args, **kwargs)
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/core/generic.py:2414, in NDFrame.to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, inf_rep, freeze_panes, storage_options, engine_kwargs)
#    2401 from pandas.io.formats.excel import ExcelFormatter
#    2403 formatter = ExcelFormatter(
#    2404     df,
#    2405     na_rep=na_rep,
#    (...)
#    2412     inf_rep=inf_rep,
#    2413 )
# -> 2414 formatter.write(
#    2415     excel_writer,
#    2416     sheet_name=sheet_name,
#    2417     startrow=startrow,
#    2418     startcol=startcol,
#    2419     freeze_panes=freeze_panes,
#    2420     engine=engine,
#    2421     storage_options=storage_options,
#    2422     engine_kwargs=engine_kwargs,
#    2423 )
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/formats/excel.py:952, in ExcelFormatter.write(self, writer, sheet_name, startrow, startcol, freeze_panes, engine, storage_options, engine_kwargs)
#     949     need_save = True
#     951 try:
# --> 952     writer._write_cells(
#     953         formatted_cells,
#     954         sheet_name,
#     955         startrow=startrow,
#     956         startcol=startcol,
#     957         freeze_panes=freeze_panes,
#     958     )
#     959 finally:
#     960     # make sure to close opened file handles
#     961     if need_save:
#
# File /opt/homebrew/lib/python3.11/site-packages/pandas/io/excel/_openpyxl.py:507, in OpenpyxlWriter._write_cells(self, cells, sheet_name, startrow, startcol, freeze_panes)
#     504         setattr(xcell, k, v)
#     506 if cell.mergestart is not None and cell.mergeend is not None:
# --> 507     wks.merge_cells(
#     508         start_row=startrow + cell.row + 1,
#     509         start_column=startcol + cell.col + 1,
#     510         end_column=startcol + cell.mergeend + 1,
#     511         end_row=startrow + cell.mergestart + 1,
#     512     )
#     514     # When cells are merged only the top-left cell is preserved
#     515     # The behaviour of the other cells in a merged range is
#     516     # undefined
#     517     if style_kwargs:
#
# File /opt/homebrew/lib/python3.11/site-packages/openpyxl/worksheet/worksheet.py:593, in Worksheet.merge_cells(self, range_string, start_row, start_column, end_row, end_column)
#     591     range_string = cr.coord
#     592 mcr = MergedCellRange(self, range_string)
# --> 593 self.merged_cells.add(mcr)
#     594 self._clean_merge_range(mcr)
#
# File /opt/homebrew/lib/python3.11/site-packages/openpyxl/worksheet/cell_range.py:462, in MultiCellRange.add(self, coord)
#     460 elif not isinstance(coord, CellRange):
#     461     raise ValueError("You can only add CellRanges")
# --> 462 if cr not in self:
#     463     self.ranges.append(cr)
#
# File /opt/homebrew/lib/python3.11/site-packages/openpyxl/worksheet/cell_range.py:436, in MultiCellRange.__contains__(self, coord)
#     434     coord = CellRange(coord)
#     435 for r in self.ranges:
# --> 436     if coord <= r:
#     437         return True
#     438 return False
#
# KeyboardInterrupt:
